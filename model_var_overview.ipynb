# %% [markdown]
# ## This notebook can be used as a quick check for variables in model list

# %%
# some inits and imports
import warnings
import os
warnings.filterwarnings('ignore')
import pyaerocom as pya
pya.change_verbosity('critical')
from helpers.model_list import get_model_ids, MODEL_DIR
# Out:
# 2018-09-27 15:08:07,318:WARNING:
# basemap extension library is not installed (or cannot be imported. Some features will not be available
# 2018-09-27 15:08:08,078:WARNING:
# geopy library is not available. Aeolus data read not enabled

# %% [markdown]
# ### Quickmode
#
# If True, the list will be created without column that include information that requires reading of the models. If True, then no *csv* file will be created.

# %%
QUICKMODE = False

# %% [markdown]
# #### Output table
#
# The result table that is created in this notebook can be found (or is stored) in the output directory (note that this table may not be available in the online repository).

# %%
OUT_FILE = 'output/model_var_overview.csv'

# %% [markdown]
# #### Directory containing model IDs

# %%
MODEL_DIR
# Out:
# '/lustre/storeA/project/aerocom/aerocom-users-database/AEROCOM-PHASE-III-CTRL2018/'

# %% [markdown]
# #### All model IDs

# %%
models = get_model_ids()
models
# Out:
# ['INCA-BCext_CTRL2016-PD',
#  'GEOS5-freegcm_CTRL2016-PD',
#  'GEOS-Chem-v11-01_AP3-CTRL2016-PD',
#  'ECMWF-IFS-CY42R1-CAMS-RA-CTRL_AP3-CTRL2016-PD',
#  'INCA-BCin_CTRL2016-PD',
#  'SPRINTARS-T213_AP3-CTRL2016-PD',
#  'ECMWF-IFS-CY43R1-CAMS-NITRATE-DEV_AP3-CTRL2016-PD',
#  'ECHAM6-SALSA_CTRL2016-PD',
#  'CNRM-AESM2_AP3-CTRL2016-PD',
#  'ECHAM6-HAM2_AP3-CTRL2016-PD',
#  'SPRINTARS-T106_AP3-CTRL2016-PD',
#  'GEOS5-replay_CTRL2016-PD',
#  'HadGEM3-GA7.1_AP3-CTRL2016-PD',
#  'CNRM-AESM2Nud_AP3-CTRL2016-PD',
#  'INCA_CTRL2016-PD',
#  'GEOS5-assimilate_CTRL2016-PD',
#  'ECHAM6.3-HAM2.3_AP3-CTRL2016-PD',
#  'CAM5.3-Oslo_AP3-CTRL2016-PD']

# %% [markdown]
# ### List of variables of interest
#
# Based on this list of variable names or patterns, an overview list will be created that provides information about the what is available in each of the above models.

# %%
VARS = ['ang4487aer', 'od550aer', 'od550lt1aer', 'ec*', 'scatc*', 'absc*', 'ssa*', 'od*3d']

# %%
df = pya.utils.create_varinfo_table(model_ids=models, 
                                    vars_or_var_patterns=VARS,
                                    read_data=not QUICKMODE,
                                    sort_by_cols=['Var', 'Model'])
# Out:
# At model: INCA-BCext_CTRL2016-PD (0 of 18)
# /home/jonasg/anaconda3/lib/python3.6/site-packages/iris/fileformats/cf.py:320: UserWarning: Missing CF-netCDF auxiliary coordinate variable 'time_centered', referenced by netCDF variable 'od550aer'
#   warnings.warn(message % (name, nc_var_name))
# /home/jonasg/anaconda3/lib/python3.6/site-packages/iris/fileformats/cf.py:645: UserWarning: Missing CF-netCDF label variable 'time_centered', referenced by netCDF variable 'od550aer'
#   warnings.warn(message % (name, nc_var_name))
# At model: GEOS5-freegcm_CTRL2016-PD (1 of 18)
# /home/jonasg/anaconda3/lib/python3.6/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1808: UserWarning: Ignoring netCDF variable 'time' invalid units 'month of year'
#   warnings.warn(msg)
# At model: GEOS-Chem-v11-01_AP3-CTRL2016-PD (2 of 18)
# At model: ECMWF-IFS-CY42R1-CAMS-RA-CTRL_AP3-CTRL2016-PD (3 of 18)
# At model: INCA-BCin_CTRL2016-PD (4 of 18)
# At model: SPRINTARS-T213_AP3-CTRL2016-PD (5 of 18)
# At model: ECMWF-IFS-CY43R1-CAMS-NITRATE-DEV_AP3-CTRL2016-PD (6 of 18)
# At model: ECHAM6-SALSA_CTRL2016-PD (7 of 18)
# At model: CNRM-AESM2_AP3-CTRL2016-PD (8 of 18)
# At model: ECHAM6-HAM2_AP3-CTRL2016-PD (9 of 18)
# At model: SPRINTARS-T106_AP3-CTRL2016-PD (10 of 18)
# At model: GEOS5-replay_CTRL2016-PD (11 of 18)
# OSError('Failed to identify file naming convention from files in model directory for model GEOS5-replay_CTRL2016-PD\ndata_dir: /lustre/storeA/project/aerocom/aerocom-users-database/AEROCOM-PHASE-III/GEOS5-replay_CTRL2016-PD/renamed',)
# At model: HadGEM3-GA7.1_AP3-CTRL2016-PD (12 of 18)
# At model: CNRM-AESM2Nud_AP3-CTRL2016-PD (13 of 18)
# At model: INCA_CTRL2016-PD (14 of 18)
# At model: GEOS5-assimilate_CTRL2016-PD (15 of 18)
# /home/jonasg/anaconda3/lib/python3.6/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1808: UserWarning: Ignoring netCDF variable 'time' invalid units 'month of year'
#   warnings.warn(msg)
# At model: ECHAM6.3-HAM2.3_AP3-CTRL2016-PD (16 of 18)
# At model: CAM5.3-Oslo_AP3-CTRL2016-PD (17 of 18)
# /home/jonasg/anaconda3/lib/python3.6/site-packages/iris/fileformats/cf.py:557: UserWarning: Missing CF-netCDF formula term variable 'hyam', referenced by netCDF variable 'lev'
#   warnings.warn(message % (variable_name, nc_var_name))
# /home/jonasg/anaconda3/lib/python3.6/site-packages/iris/fileformats/cf.py:557: UserWarning: Missing CF-netCDF formula term variable 'hybm', referenced by netCDF variable 'lev'
#   warnings.warn(message % (variable_name, nc_var_name))
# /home/jonasg/anaconda3/lib/python3.6/site-packages/iris/fileformats/cf.py:557: UserWarning: Missing CF-netCDF formula term variable 'P0', referenced by netCDF variable 'lev'
#   warnings.warn(message % (variable_name, nc_var_name))
# /home/jonasg/anaconda3/lib/python3.6/site-packages/iris/fileformats/cf.py:557: UserWarning: Missing CF-netCDF formula term variable 'PS', referenced by netCDF variable 'lev'
#   warnings.warn(message % (variable_name, nc_var_name))
# /home/jonasg/anaconda3/lib/python3.6/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1808: UserWarning: Ignoring netCDF variable 'lev' invalid units 'level'
#   warnings.warn(msg)
# /home/jonasg/anaconda3/lib/python3.6/site-packages/iris/fileformats/cf.py:557: UserWarning: Missing CF-netCDF formula term variable 'hyam', referenced by netCDF variable 'lev'
#   warnings.warn(message % (variable_name, nc_var_name))
# /home/jonasg/anaconda3/lib/python3.6/site-packages/iris/fileformats/cf.py:557: UserWarning: Missing CF-netCDF formula term variable 'hybm', referenced by netCDF variable 'lev'
#   warnings.warn(message % (variable_name, nc_var_name))
# /home/jonasg/anaconda3/lib/python3.6/site-packages/iris/fileformats/cf.py:557: UserWarning: Missing CF-netCDF formula term variable 'P0', referenced by netCDF variable 'lev'
#   warnings.warn(message % (variable_name, nc_var_name))
# /home/jonasg/anaconda3/lib/python3.6/site-packages/iris/fileformats/cf.py:557: UserWarning: Missing CF-netCDF formula term variable 'PS', referenced by netCDF variable 'lev'
#   warnings.warn(message % (variable_name, nc_var_name))
# /home/jonasg/anaconda3/lib/python3.6/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1808: UserWarning: Ignoring netCDF variable 'lev' invalid units 'level'
#   warnings.warn(msg)

# %% [markdown]
# #### Save table as csv (if applicable)

# %%
if not QUICKMODE or not os.path.exists(OUT_FILE):
    df.to_csv(OUT_FILE)

# %% [markdown]
# #### Display overview table

# %%
from helpers.pandas import _dataframe_highlight_4d_no_altitude_dim
df.style.apply(_dataframe_highlight_4d_no_altitude_dim, axis=None)
# Out:
# /home/jonasg/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py:180: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   .format(op=op_str, alt_op=unsupported[op_str]))
# <style  type="text/css" >
#     #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow0_col0 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow0_col1 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow0_col2 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow0_col3 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow0_col4 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow0_col5 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow0_col6 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow0_col7 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow0_col8 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow0_col9 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow0_col10 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow1_col0 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow1_col1 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow1_col2 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow1_col3 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow1_col4 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow1_col5 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow1_col6 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow1_col7 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow1_col8 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow1_col9 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow1_col10 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow2_col0 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow2_col1 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow2_col2 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow2_col3 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow2_col4 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow2_col5 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow2_col6 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow2_col7 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow2_col8 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow2_col9 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow2_col10 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow3_col0 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow3_col1 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow3_col2 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow3_col3 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow3_col4 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow3_col5 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow3_col6 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow3_col7 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow3_col8 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow3_col9 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow3_col10 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow4_col0 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow4_col1 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow4_col2 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow4_col3 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow4_col4 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow4_col5 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow4_col6 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow4_col7 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow4_col8 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow4_col9 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow4_col10 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow5_col0 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow5_col1 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow5_col2 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow5_col3 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow5_col4 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow5_col5 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow5_col6 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow5_col7 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow5_col8 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow5_col9 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow5_col10 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow6_col0 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow6_col1 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow6_col2 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow6_col3 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow6_col4 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow6_col5 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow6_col6 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow6_col7 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow6_col8 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow6_col9 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow6_col10 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow7_col0 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow7_col1 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow7_col2 {
#             background-color:  "";
#         }    #T_5c3ffc76_c258_11e8_944c_80ce6220aa9erow7
